# %%
using Plots; plotlyjs();    # PlotlyJS backend
using DensityInterpolationMethod
using DensityInterpolationMethod.Mesh
using DensityInterpolationMethod.Utils 
using DensityInterpolationMethod.IO
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-1491222695323060991\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-5223164865638078600\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-1491222695323060991\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")

# %%
# Read mesh
ELEM_ORDER = 1    # element order
HMAX = 1          # max mesh size
mesh_filename = "../test/meshes/sphere1.geo"

mesh = read_gmsh_geo(mesh_filename, h=HMAX, order=ELEM_ORDER);
# Out:
# Info    : Reading '../test/meshes/sphere1.geo'...
# Info    : Done reading '../test/meshes/sphere1.geo'
# Info    : Meshing 1D...
# Info    : [ 40%] Meshing curve 2 (Circle)
# Info    : Done meshing 1D (Wall 0.000149012s, CPU 0.000145s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Sphere, MeshAdapt)
# Info    : Done meshing 2D (Wall 0.0418501s, CPU 0.041761s)
# Info    : 33 nodes 68 elements

# %% [markdown]
# # Mesh node plot

# %%
meshplot(mesh, centers=false, normals=0.5, tangents=0, fmt=:svg)

# %% [markdown]
# # Mesh surface plot
# NOTE: It is possible that some elements may not be displayed properly.

# %%
surfacemeshplot(mesh, npoints=10, fmt = :svg)
meshplot!(mesh, nodes=false, normals=0.5)

# %% [markdown]
# # Plots also work on quadratic elements

# %%
# Read mesh
ELEM_ORDER = 2    # element order
mesh = read_gmsh_geo(mesh_filename, h=HMAX, order=ELEM_ORDER);
# Out:
# Info    : Reading '../test/meshes/sphere1.geo'...
# Info    : Done reading '../test/meshes/sphere1.geo'
# Info    : Meshing 1D...
# Info    : [ 40%] Meshing curve 2 (Circle)
# Info    : Done meshing 1D (Wall 0.000138998s, CPU 0.000142s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Sphere, MeshAdapt)
# Info    : Done meshing 2D (Wall 0.12154s, CPU 0.067225s)
# Info    : Meshing order 2 (curvilinear on)...
# Info    : [  0%] Meshing curve 1 order 2
# Info    : [ 20%] Meshing curve 2 order 2
# Info    : [ 40%] Meshing curve 3 order 2
# Info    : [ 60%] Meshing surface 1 order 2
# Info    : [ 80%] Meshing volume 1 order 2
# Info    : Surface mesh: worst distortion = 0.968124 (0 elements in ]0, 0.2]); worst gamma = 0.659556
# Info    : Done meshing order 2 (Wall 0.00139499s, CPU 0.001389s)
# Info    : 126 nodes 68 elements

# %%
meshplot(mesh, centers=false, normals=0.5, tangents=0, fmt=:svg)

# %%
# NOTE: It is possible that some elements may not be displayed properly.
surfacemeshplot(mesh, npoints=10, fmt = :svg)
meshplot!(mesh, nodes=false, normals=0.5)
